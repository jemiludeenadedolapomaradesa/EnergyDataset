# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('EnergyDataSet.csv')

#renaming columns

column_names = {'date' : 'Date', 'Appliances': 'energy_use', 'lights': 'energy_use_of_light', 'T1': 'Temperature_in_kitchen_area',
                'RH_1': 'Humidity_in_kitchen_area', 'T2': "Temperature_in_livingroom", 'RH_2': 'Humidity_in_livingroom',
                'T3': 'Temperature_in_laundryroom', 'RH_3': 'Humidity_in_laundaryroom', 'T4': 'Temperature_in_officeroom',
                'RH-4': 'Humidity_in_officeroom', 'T5': 'Temperature_in_bathroom', 'RH_5': 'Humidity_in_bathroom', 'T6': 'Temperature_outside_the_building',
                'RH_6': 'Humidity_outside_the_building', 'T7': 'Temperature_in_ironingroom', 'RH_7': 'Humidity_in_ironingroom', 'T8': 'Temperature_in_tenagerroom',
                'RH_8': 'Humidity_in_teenagerroom', 'T9': 'Temperature_in_parentsroom', 'RH_9': 'Humidity_in_parentsroom', 'T_out':"Temperature_outside", 'Press_mm_hg': 'pressure',
                'RH_out':'Himidity_outside', 'Windspeed': 'Winspeed', 'Visibility': 'Visibility',  'Tdewpoint': 'Tdewpoint', 'rv1': 'Random_Variable_1', 'rv2' : 'Random_Variable_2'}

df = df.rename(columns= column_names) #rename columns
simple_linear_reg_df = df[['Temperature_in_kitchen_area', 'Temperature_in_bathroom']].sample(15, random_state=2)
sns.regplot(x='Temperature_in_kitchen_area', y= 'Temperature_in_bathroom', data=simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='Temperature_in_kitchen_area', ylabel='Temperature_in_bathroom'>

# %%
df.describe()
# Out:
#          energy_use  energy_use_of_light  Temperature_in_kitchen_area  \
# count  19735.000000         19735.000000                 19735.000000
# mean      97.694958             3.801875                    21.686571
# std      102.524891             7.935988                     1.606066
# min       10.000000             0.000000                    16.790000
# 25%       50.000000             0.000000                    20.760000
# 50%       60.000000             0.000000                    21.600000
# 75%      100.000000             0.000000                    22.600000
# max     1080.000000            70.000000                    26.260000
#
#        Humidity_in_kitchen_area  Temperature_in_livingroom  \
# count              19735.000000               19735.000000
# mean                  40.259739                  20.341219
# std                    3.979299                   2.192974
# min                   27.023333                  16.100000
# ...

# %%
#Mean Absolute Value

from sklearn.preprocessing import MinMaxScaler 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_value
scaler = MinMaxScaler()                             #creating an instance 
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns= df.columns)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2324/1422797148.py in <module>
#       4 from sklearn.linear_model import LinearRegression
#       5 from sklearn.model_selection import train_test_split
# ----> 6 from sklearn.metrics import mean_absolute_value
#       7 scaler = MinMaxScaler()                             #creating an instance
#       8 normalised_df = pd.DataFrame(scaler.fit_transform(df), columns= df.columns)
#
# ImportError: cannot import name 'mean_absolute_value' from 'sklearn.metrics' (c:\Users\MARAD\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)
